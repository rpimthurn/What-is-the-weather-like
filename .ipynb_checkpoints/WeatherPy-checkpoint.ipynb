# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
api_key
# Out:
# 'e316f91094d626c046b3077c84c0d13e'

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 604

# %%
city2 = cities[3]
city2
# Out:
# 'vardo'

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_name = []
country = []
max_temp = []
wind_speed = []
cloudiness = []
humidity = []
lat = []
long = []
date = []

# %%
url = "http://api.openweathermap.org/data/2.5/weather"

# %%
        payload = {
            "appid": api_key,
            "q": city2,
            "units": "imperial"
        }
        r = requests.get(url, params=payload).json()
        r
# Out:
# {'coord': {'lon': -77.74, 'lat': 39.62},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 58.44,
#   'feels_like': 53.83,
#   'temp_min': 53.6,
#   'temp_max': 62.01,
#   'pressure': 1024,
#   'humidity': 55},
#  'visibility': 16093,
#  'wind': {'speed': 5.08, 'deg': 319},
#  'clouds': {'all': 1},
#  'dt': 1577552564,
#  'sys': {'type': 1,
#   'id': 4970,
#   'country': 'US',
#   'sunrise': 1577536247,
#   'sunset': 1577570029},
#  'timezone': -18000,
#  'id': 4372777,
#  'name': 'Vardo',
#  'cod': 200}

# %%
record_value = 0
set_value = 1

# %%
for city in cities:
        
    try:          
        payload = {
            "appid": api_key,
            "q": city,
            "units": "imperial"
        }
        r = requests.get(url, params=payload).json()
        city_name.append(r["name"])
        country.append(r["sys"]["country"])
        max_temp.append(r["main"]["temp_max"])
        wind_speed.append(r["wind"]["speed"])
        cloudiness.append(r["clouds"]["all"])
        humidity.append(r["main"]["humidity"])
        lat.append(r["coord"]["lat"])
        long.append(r["coord"]["lon"])
        date.append(r["dt"])
        
        if record_value < 50:
            print("Processing Record " + str(record_value) + " of Set " + str(set_value) + " | " + city)
            record_value += 1
        else:
            record_value = 0
            set_value += 1
            
        
    except:
        print("City not found. Skipping...")
# Out:
# Processing Record 0 of Set 1 | ahipara
# Processing Record 1 of Set 1 | lugovoy
# Processing Record 2 of Set 1 | saint george
# Processing Record 3 of Set 1 | vardo
# Processing Record 4 of Set 1 | hrodna
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | lagoa
# Processing Record 7 of Set 1 | cortez
# Processing Record 8 of Set 1 | bellevue
# Processing Record 9 of Set 1 | sulangan
# Processing Record 10 of Set 1 | butaritari
# Processing Record 11 of Set 1 | upernavik
# Processing Record 12 of Set 1 | hermanus
# City not found. Skipping...
# Processing Record 13 of Set 1 | dikson
# City not found. Skipping...
# Processing Record 14 of Set 1 | ambon
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | upata
# Processing Record 18 of Set 1 | sur
# Processing Record 19 of Set 1 | mataura
# City not found. Skipping...
# Processing Record 20 of Set 1 | los llanos de aridane
# Processing Record 21 of Set 1 | airai
# Processing Record 22 of Set 1 | pangnirtung
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | hithadhoo
# Processing Record 25 of Set 1 | kodiak
# Processing Record 26 of Set 1 | nurota
# Processing Record 27 of Set 1 | tessalit
# Processing Record 28 of Set 1 | husavik
# Processing Record 29 of Set 1 | saint-francois
# Processing Record 30 of Set 1 | guerrero negro
# Processing Record 31 of Set 1 | jamestown
# City not found. Skipping...
# Processing Record 30 of Set 4 | jacmel
# Processing Record 31 of Set 4 | tuktoyaktuk
# City not found. Skipping...
# Processing Record 32 of Set 4 | ostrovnoy
# Processing Record 33 of Set 4 | dondo
# Processing Record 34 of Set 4 | rassvet
# Processing Record 35 of Set 4 | alofi
# Processing Record 36 of Set 4 | the pas
# Processing Record 37 of Set 4 | mahibadhoo
# Processing Record 38 of Set 4 | port alfred
# Processing Record 39 of Set 4 | rocha
# City not found. Skipping...
# Processing Record 40 of Set 4 | velyka oleksandrivka
# Processing Record 41 of Set 4 | mattru
# Processing Record 42 of Set 4 | wenatchee
# Processing Record 43 of Set 4 | tilichiki
# Processing Record 44 of Set 4 | concordia
# Processing Record 45 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 4 | cockburn town
# Processing Record 47 of Set 4 | banjar
# Processing Record 48 of Set 4 | cherskiy
# Processing Record 49 of Set 4 | kytmanovo
# Processing Record 0 of Set 5 | sao felix do xingu
# Processing Record 1 of Set 5 | miri
# Processing Record 2 of Set 5 | morant bay
# Processing Record 3 of Set 5 | egvekinot
# Processing Record 4 of Set 5 | huari
# Processing Record 5 of Set 5 | victoria
# Processing Record 6 of Set 5 | itacoatiara
# Processing Record 7 of Set 5 | sinnamary
# Processing Record 8 of Set 5 | chuy
# Processing Record 9 of Set 5 | joshimath
# Processing Record 10 of Set 5 | khatanga
# Processing Record 11 of Set 5 | avera
# Processing Record 12 of Set 5 | nunoa
# Processing Record 13 of Set 5 | killin
# Processing Record 14 of Set 5 | pereslavl-zalesskiy
# Processing Record 15 of Set 5 | dengfeng
# Processing Record 16 of Set 5 | tiksi
# Processing Record 17 of Set 5 | wanning
# Processing Record 18 of Set 5 | kruisfontein
# Processing Record 19 of Set 5 | livadia
# Processing Record 20 of Set 5 | camacha
# Processing Record 21 of Set 5 | neryungri
# Processing Record 22 of Set 5 | korcula
# Processing Record 23 of Set 5 | bandar
# Processing Record 24 of Set 5 | belmonte
# City not found. Skipping...
# Processing Record 25 of Set 5 | puerto del rosario
# Processing Record 26 of Set 5 | port blair
# Processing Record 27 of Set 5 | praxedis guerrero
# Processing Record 28 of Set 5 | unteni
# Processing Record 29 of Set 5 | pevek
# Processing Record 30 of Set 5 | chimbote
# Processing Record 31 of Set 5 | barreirinhas
# City not found. Skipping...
# Processing Record 32 of Set 5 | sambava
# Processing Record 33 of Set 5 | zeya
# Processing Record 34 of Set 5 | thinadhoo
# Processing Record 35 of Set 5 | ozernovskiy
# Processing Record 36 of Set 5 | kahului
# Processing Record 37 of Set 5 | geraldton
# Processing Record 38 of Set 5 | piossasco
# Processing Record 39 of Set 5 | matamoros
# Processing Record 40 of Set 5 | fukue
# Processing Record 41 of Set 5 | sitka
# Processing Record 42 of Set 5 | owando
# Processing Record 43 of Set 5 | bodden town
# Processing Record 44 of Set 5 | el retorno
# Processing Record 45 of Set 5 | norman wells
# Processing Record 46 of Set 5 | sukhodol
# Processing Record 47 of Set 5 | arraial do cabo
# Processing Record 48 of Set 5 | buta
# Processing Record 49 of Set 5 | wajir
# Processing Record 0 of Set 6 | launceston
# Processing Record 1 of Set 6 | verkhniye tatyshly
# Processing Record 2 of Set 6 | margate
# Processing Record 3 of Set 6 | chapais
# Processing Record 4 of Set 6 | ancud
# Processing Record 5 of Set 6 | bani walid
# Processing Record 6 of Set 6 | nikolskoye
# City not found. Skipping...
# Processing Record 7 of Set 6 | roncesvalles
# Processing Record 8 of Set 6 | moree
# Processing Record 9 of Set 6 | moussoro
# Processing Record 10 of Set 6 | qaqortoq
# Processing Record 11 of Set 6 | georgetown
# City not found. Skipping...
# Processing Record 12 of Set 6 | yulara
# Processing Record 13 of Set 6 | khani
# City not found. Skipping...
# Processing Record 14 of Set 6 | novosergiyevka
# Processing Record 15 of Set 6 | tshikapa
# Processing Record 16 of Set 6 | zaysan
# City not found. Skipping...
# Processing Record 17 of Set 6 | ust-nera
# Processing Record 18 of Set 6 | chitrakonda
# Processing Record 19 of Set 6 | waipawa
# Processing Record 20 of Set 6 | mpika
# Processing Record 21 of Set 6 | isangel
# Processing Record 22 of Set 6 | taltal
# Processing Record 23 of Set 6 | badoc
# Processing Record 24 of Set 6 | grand gaube
# Processing Record 25 of Set 6 | anadyr
# Processing Record 26 of Set 6 | sao joao da barra
# Processing Record 27 of Set 6 | eloy
# Processing Record 28 of Set 6 | capao bonito
# Processing Record 29 of Set 6 | sangar
# Processing Record 30 of Set 6 | aksarka
# Processing Record 31 of Set 6 | payo
# Processing Record 32 of Set 6 | kavieng
# Processing Record 33 of Set 6 | omsukchan
# Processing Record 34 of Set 6 | dabakala
# City not found. Skipping...
# Processing Record 35 of Set 6 | broken hill
# Processing Record 36 of Set 6 | twante
# City not found. Skipping...
# Processing Record 37 of Set 6 | portland
# Processing Record 38 of Set 6 | leme
# Processing Record 39 of Set 6 | le passage
# Processing Record 40 of Set 6 | praia
# Processing Record 41 of Set 6 | constitucion
# Processing Record 42 of Set 6 | jertih
# Processing Record 43 of Set 6 | kaliningrad
# Processing Record 44 of Set 6 | cascais
# Processing Record 45 of Set 6 | chivay
# Processing Record 46 of Set 6 | tiznit
# Processing Record 47 of Set 6 | bara
# Processing Record 48 of Set 6 | minas
# City not found. Skipping...
# Processing Record 49 of Set 6 | sorland
# Processing Record 0 of Set 7 | gobabis
# Processing Record 1 of Set 7 | eston
# Processing Record 2 of Set 7 | kosmynino
# Processing Record 3 of Set 7 | yumen
# Processing Record 4 of Set 7 | syzran
# Processing Record 5 of Set 7 | san jose
# Processing Record 6 of Set 7 | narsaq
# Processing Record 7 of Set 7 | sawakin
# Processing Record 8 of Set 7 | saint anthony
# Processing Record 9 of Set 7 | lithakia
# Processing Record 10 of Set 7 | kjollefjord
# Processing Record 11 of Set 7 | kholodnyy
# Processing Record 12 of Set 7 | ossora
# Processing Record 13 of Set 7 | bilokurakyne
# Processing Record 14 of Set 7 | berlevag
# Processing Record 15 of Set 7 | toyooka
# Processing Record 16 of Set 7 | kiama
# Processing Record 17 of Set 7 | manaure
# Processing Record 18 of Set 7 | coquimbo
# Processing Record 19 of Set 7 | samarai
# Processing Record 20 of Set 7 | khovu-aksy
# Processing Record 21 of Set 7 | poum
# Processing Record 22 of Set 7 | arys
# Processing Record 23 of Set 7 | zapolyarnyy
# Processing Record 24 of Set 7 | dali
# City not found. Skipping...
# Processing Record 25 of Set 7 | oksfjord
# Processing Record 26 of Set 7 | hobyo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 49 of Set 8 | lar
# Processing Record 0 of Set 9 | santa maria
# Processing Record 1 of Set 9 | beira
# Processing Record 2 of Set 9 | noumea
# Processing Record 3 of Set 9 | conakry
# Processing Record 4 of Set 9 | vyazma
# Processing Record 5 of Set 9 | mackay
# Processing Record 6 of Set 9 | mizdah
# Processing Record 7 of Set 9 | deputatskiy
# Processing Record 8 of Set 9 | dwarka
# Processing Record 9 of Set 9 | katsuura
# Processing Record 10 of Set 9 | red bluff
# Processing Record 11 of Set 9 | jorpeland
# City not found. Skipping...
# Processing Record 12 of Set 9 | allschwil
# Processing Record 13 of Set 9 | vao
# Processing Record 14 of Set 9 | dekar
# Processing Record 15 of Set 9 | namatanai
# Processing Record 16 of Set 9 | biu
# Processing Record 17 of Set 9 | ust-kuyga
# Processing Record 18 of Set 9 | karratha
# Processing Record 19 of Set 9 | bathsheba
# Processing Record 20 of Set 9 | talara
# Processing Record 21 of Set 9 | soyo
# Processing Record 22 of Set 9 | dezful
# Processing Record 23 of Set 9 | oxford
# City not found. Skipping...
# Processing Record 24 of Set 9 | northam
# City not found. Skipping...
# Processing Record 25 of Set 9 | lorengau
# Processing Record 26 of Set 9 | iracoubo
# Processing Record 27 of Set 9 | labuhan
# Processing Record 28 of Set 9 | vavuniya
# Processing Record 29 of Set 9 | plaster rock
# Processing Record 30 of Set 9 | brae
# Processing Record 31 of Set 9 | mareeba
# Processing Record 32 of Set 9 | faanui
# Processing Record 33 of Set 9 | tommot
# Processing Record 34 of Set 9 | murwillumbah
# Processing Record 35 of Set 9 | adrar
# Processing Record 36 of Set 9 | cabra
# Processing Record 37 of Set 9 | weymouth
# City not found. Skipping...
# Processing Record 38 of Set 9 | port hawkesbury
# Processing Record 39 of Set 9 | hay river
# Processing Record 40 of Set 9 | praia da vitoria
# Processing Record 41 of Set 9 | vila franca do campo
# Processing Record 42 of Set 9 | marsa matruh
# Processing Record 43 of Set 9 | tottori
# Processing Record 44 of Set 9 | rudsar
# Processing Record 45 of Set 9 | sabha
# Processing Record 46 of Set 9 | fiche
# Processing Record 47 of Set 9 | mount isa
# Processing Record 48 of Set 9 | coahuayana
# Processing Record 49 of Set 9 | goma
# Processing Record 0 of Set 10 | collie
# Processing Record 1 of Set 10 | the valley
# Processing Record 2 of Set 10 | chau doc
# Processing Record 3 of Set 10 | jinka
# Processing Record 4 of Set 10 | haileybury
# Processing Record 5 of Set 10 | ulladulla
# Processing Record 6 of Set 10 | tuatapere
# Processing Record 7 of Set 10 | kangaba
# Processing Record 8 of Set 10 | iskateley
# Processing Record 9 of Set 10 | cayenne
# Processing Record 10 of Set 10 | kiruna
# Processing Record 11 of Set 10 | san martin
# Processing Record 12 of Set 10 | kichera
# Processing Record 13 of Set 10 | labytnangi
# Processing Record 14 of Set 10 | orsk
# Processing Record 15 of Set 10 | mao
# Processing Record 16 of Set 10 | tabou
# City not found. Skipping...
# Processing Record 17 of Set 10 | vestmannaeyjar
# City not found. Skipping...
# Processing Record 18 of Set 10 | huilong
# Processing Record 19 of Set 10 | cao bang
# Processing Record 20 of Set 10 | ayia galini
# Processing Record 21 of Set 10 | nsoko
# Processing Record 22 of Set 10 | nome
# Processing Record 23 of Set 10 | nakanojo
# Processing Record 24 of Set 10 | utica
# City not found. Skipping...
# Processing Record 25 of Set 10 | requena
# Processing Record 26 of Set 10 | sunrise manor
# City not found. Skipping...
# Processing Record 27 of Set 10 | nantucket
# City not found. Skipping...
# Processing Record 28 of Set 10 | vadu moldovei
# Processing Record 29 of Set 10 | inhambane
# Processing Record 30 of Set 10 | mecca
# Processing Record 31 of Set 10 | uvira
# Processing Record 32 of Set 10 | gushikawa
# Processing Record 33 of Set 10 | gizo
# Processing Record 34 of Set 10 | barranca
# Processing Record 35 of Set 10 | pisco
# Processing Record 36 of Set 10 | turbat
# Processing Record 37 of Set 10 | brainerd
# Processing Record 38 of Set 10 | abbotsford
# Processing Record 39 of Set 10 | fortuna
# Processing Record 40 of Set 10 | kasongo-lunda
# Processing Record 41 of Set 10 | xichang
# City not found. Skipping...
# Processing Record 42 of Set 10 | suntar
# City not found. Skipping...
# Processing Record 43 of Set 10 | santa cruz
# Processing Record 44 of Set 10 | doha
# Processing Record 45 of Set 10 | balsas
# Processing Record 46 of Set 10 | kushiro
# Processing Record 47 of Set 10 | santa fe
# Processing Record 48 of Set 10 | mazatlan
# Processing Record 49 of Set 10 | karoi
# City not found. Skipping...
# Processing Record 0 of Set 11 | unity
# Processing Record 1 of Set 11 | hualmay
# Processing Record 2 of Set 11 | manokwari
# Processing Record 3 of Set 11 | san julian
# Processing Record 4 of Set 11 | bell ville
# Processing Record 5 of Set 11 | roma
# Processing Record 6 of Set 11 | saurimo
# Processing Record 7 of Set 11 | chernyshevskiy
# Processing Record 8 of Set 11 | san andres
# Processing Record 9 of Set 11 | novikovo
# Processing Record 10 of Set 11 | nemuro
# City not found. Skipping...
# Processing Record 11 of Set 11 | tahe
# City not found. Skipping...
# Processing Record 12 of Set 11 | ariquemes
# Processing Record 13 of Set 11 | cabinda
# Processing Record 14 of Set 11 | bilibino
# Processing Record 15 of Set 11 | maceio
# Processing Record 16 of Set 11 | jumla
# Processing Record 17 of Set 11 | sao borja
# Processing Record 18 of Set 11 | xiashi
# City not found. Skipping...
# Processing Record 19 of Set 11 | iquitos
# Processing Record 20 of Set 11 | kailua
# Processing Record 21 of Set 11 | meadow lake
# Processing Record 22 of Set 11 | maniitsoq
# Processing Record 23 of Set 11 | zomin
# Processing Record 24 of Set 11 | nishihara
# Processing Record 25 of Set 11 | sorrento
# Processing Record 26 of Set 11 | diego de almagro
# Processing Record 27 of Set 11 | ambilobe
# City not found. Skipping...
# Processing Record 28 of Set 11 | carballo
# Processing Record 29 of Set 11 | socorro
# Processing Record 30 of Set 11 | walvis bay
# Processing Record 31 of Set 11 | touros
# Processing Record 32 of Set 11 | plettenberg bay

# %%
len(city_name)
# Out:
# 543

# %%
pd.DataFrame({"name": city_name,
              "country": country})
# Out:
#                 name country
# 0            Ahipara      NZ
# 1            Lugovoy      RU
# 2       Saint George      GR
# 3              Vardo      US
# 4             Hrodna      BY
# ..               ...     ...
# 538         Carballo      ES
# 539          Socorro      US
# 540       Walvis Bay      NA
# 541           Touros      BR
# 542  Plettenberg Bay      ZA
#
# [543 rows x 2 columns]

# %%
len(country)

# %%
len(humidity)

# %%
len(cloudiness)

# %%
len(wind_speed)

# %%
len(max_temp)

# %%
len(lat)

# %%
len(long)

# %%
len(date)
